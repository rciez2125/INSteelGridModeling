# %%
# this block left as program initialization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# This code is for reading xlsx files and generatng figures of the electricity capacity and generation

# Initialize dictionaries to store data
gen_data = {}
cap_data = {}
all_data = {}

# File names for the two Excel files
cap_file = "combined_cap_ivrt.xlsx"
gen_file = "combined_gen_ivrt.xlsx"

# Read from combined_cap_ivrt.xlsx and update cap_data
try:
    cap_sheets = pd.ExcelFile(cap_file).sheet_names
    for sheet_name in cap_sheets:
        try:
            df = pd.read_excel(cap_file, sheet_name=sheet_name)
            key = f"{sheet_name}_ivrt.csv"  # Modify the key for cap_data
            cap_data[key] = df
            all_data[key] = df
            print(f"Successfully loaded sheet '{sheet_name}' from {cap_file}")
        except Exception as e:
            print(f"Error loading sheet '{sheet_name}' from {cap_file}: {e}")
except FileNotFoundError:
    print(f"File not found: {cap_file}")
except Exception as e:
    print(f"Error reading {cap_file}: {e}")

# Read from combined_gen_ivrt.xlsx and update gen_data
try:
    gen_sheets = pd.ExcelFile(gen_file).sheet_names
    for sheet_name in gen_sheets:
        try:
            df = pd.read_excel(gen_file, sheet_name=sheet_name)
            key = f"{sheet_name}_ivrt.csv"  # Modify the key for gen_data
            gen_data[key] = df
            all_data[key] = df
            print(f"Successfully loaded sheet '{sheet_name}' from {gen_file}")
        except Exception as e:
            print(f"Error loading sheet '{sheet_name}' from {gen_file}: {e}")
except FileNotFoundError:
    print(f"File not found: {gen_file}")
except Exception as e:
    print(f"Error reading {gen_file}: {e}")

print(f"\nTotal sheets loaded for capacity data: {len(cap_data)}")
print(f"Total sheets loaded for generation data: {len(gen_data)}")
# Out:
# Successfully loaded sheet '98pc10yr_nuclear_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_re_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_solar_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_wind_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_mid_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pcins_nuclear_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pcins_re_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pcins_solar_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pcins_wind_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pcins_mid_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'base_nuclear_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'base_re_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'base_solar_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'base_wind_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'base_mid_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'med10yr_nuclear_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'med10yr_re_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'med10yr_solar_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'med10yr_wind_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'med10yr_mid_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'medins_nuclear_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'medins_re_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'medins_solar_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'medins_wind_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet 'medins_mid_cap' from combined_cap_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_nuclear_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_re_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_solar_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_wind_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pc10yr_mid_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pcins_nuclear_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pcins_re_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pcins_solar_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pcins_wind_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet '98pcins_mid_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'base_nuclear_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'base_re_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'base_solar_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'base_wind_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'base_mid_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'med10yr_nuclear_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'med10yr_re_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'med10yr_solar_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'med10yr_wind_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'med10yr_mid_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'medins_nuclear_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'medins_re_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'medins_solar_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'medins_wind_gen' from combined_gen_ivrt.xlsx
# Successfully loaded sheet 'medins_mid_gen' from combined_gen_ivrt.xlsx
#
# Total sheets loaded for capacity data: 25
# Total sheets loaded for generation data: 25

# %%
# filter out northern Indiana data (p105)
indiana_all_data = {}

for file_name, data in all_data.items():
    try:
        if 'r' in data.columns:
            indiana_all_data[file_name] = data[data['r'] == 'p105']
            print(f'Filterred data for: {file_name}')
        else:
            print(f'Column 'r' not found in {file_name}, skipping.')
    except Exception as e:
        print(f'Error processing {file_name}: {e}')

print(f'Total files processed: {len(indiana_all_data)}')

for file_name, data in indiana_all_data.items():
    print(f'\nPreview of {file_name}:')
    print(data.head(10))
    print("\n" + "="*50 + "\n")
# Out:
# Filterred data for: 98pc10yr_nuclear_cap_ivrt.csv
# Filterred data for: 98pc10yr_re_cap_ivrt.csv
# Filterred data for: 98pc10yr_solar_cap_ivrt.csv
# Filterred data for: 98pc10yr_wind_cap_ivrt.csv
# Filterred data for: 98pc10yr_mid_cap_ivrt.csv
# Filterred data for: 98pcins_nuclear_cap_ivrt.csv
# Filterred data for: 98pcins_re_cap_ivrt.csv
# Filterred data for: 98pcins_solar_cap_ivrt.csv
# Filterred data for: 98pcins_wind_cap_ivrt.csv
# Filterred data for: 98pcins_mid_cap_ivrt.csv
# Filterred data for: base_nuclear_cap_ivrt.csv
# Filterred data for: base_re_cap_ivrt.csv
# Filterred data for: base_solar_cap_ivrt.csv
# Filterred data for: base_wind_cap_ivrt.csv
# Filterred data for: base_mid_cap_ivrt.csv
# Filterred data for: med10yr_nuclear_cap_ivrt.csv
# Filterred data for: med10yr_re_cap_ivrt.csv
# Filterred data for: med10yr_solar_cap_ivrt.csv
# Filterred data for: med10yr_wind_cap_ivrt.csv
# Filterred data for: med10yr_mid_cap_ivrt.csv
# Filterred data for: medins_nuclear_cap_ivrt.csv
# Filterred data for: medins_re_cap_ivrt.csv
# Filterred data for: medins_solar_cap_ivrt.csv
# Filterred data for: medins_wind_cap_ivrt.csv
# Filterred data for: medins_mid_cap_ivrt.csv
# Filterred data for: 98pc10yr_nuclear_gen_ivrt.csv
# Filterred data for: 98pc10yr_re_gen_ivrt.csv
# Filterred data for: 98pc10yr_solar_gen_ivrt.csv
# Filterred data for: 98pc10yr_wind_gen_ivrt.csv
# Filterred data for: 98pc10yr_mid_gen_ivrt.csv
# Filterred data for: 98pcins_nuclear_gen_ivrt.csv
# Filterred data for: 98pcins_re_gen_ivrt.csv
# Filterred data for: 98pcins_solar_gen_ivrt.csv
# Filterred data for: 98pcins_wind_gen_ivrt.csv
# Filterred data for: 98pcins_mid_gen_ivrt.csv
# Filterred data for: base_nuclear_gen_ivrt.csv
# Filterred data for: base_re_gen_ivrt.csv
# Filterred data for: base_solar_gen_ivrt.csv
# Filterred data for: base_wind_gen_ivrt.csv
# Filterred data for: base_mid_gen_ivrt.csv
# Filterred data for: med10yr_nuclear_gen_ivrt.csv
# Filterred data for: med10yr_re_gen_ivrt.csv
# Filterred data for: med10yr_solar_gen_ivrt.csv
# Filterred data for: med10yr_wind_gen_ivrt.csv
# Filterred data for: med10yr_mid_gen_ivrt.csv
# Filterred data for: medins_nuclear_gen_ivrt.csv
# Filterred data for: medins_re_gen_ivrt.csv
# Filterred data for: medins_solar_gen_ivrt.csv
# Filterred data for: medins_wind_gen_ivrt.csv
# Filterred data for: medins_mid_gen_ivrt.csv
# Total files processed: 50
#
# Preview of 98pc10yr_nuclear_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
# 132  battery_2    new8  p105  2025  2.273737e-13
# 133  battery_2    new8  p105  2030  2.273737e-13
# 134  battery_2    new8  p105  2035  2.273737e-13
# 572  battery_4   new18  p105  2035  3.183250e-01
# 573  battery_4   new18  p105  2040  3.183250e-01
# 574  battery_4   new18  p105  2045  3.183250e-01
# 763  battery_4   new33  p105  2050  6.823898e+02
#
# ==================================================
#
#
# Preview of 98pc10yr_re_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
#
# 0    battery_2  init-1  p105  2010     2.000000
# 1    battery_2  init-1  p105  2015     2.000000
# 2    battery_2  init-1  p105  2020     2.000000
# 375  battery_2   new33  p105  2050    30.450368
# 439  battery_4    new8  p105  2025   156.484127
# 440  battery_4    new8  p105  2030   156.484127
# 441  battery_4    new8  p105  2035   156.484127
# 676  battery_4   new18  p105  2035  1577.202010
# 677  battery_4   new18  p105  2040  1577.202010
# 678  battery_4   new18  p105  2045  1577.202010
#
# ==================================================
#
#
# Preview of 98pcins_wind_cap_ivrt.csv:
#              i       v     r     t         Val
# 0    battery_2  init-1  p105  2010    2.000000
# 1    battery_2  init-1  p105  2015    2.000000
# 2    battery_2  init-1  p105  2020    2.000000
# 297  battery_2   new23  p105  2040   30.957850
# 298  battery_2   new23  p105  2045   30.957850
# 299  battery_2   new23  p105  2050   30.957850
# 424  battery_4    new8  p105  2025    3.027183
# 425  battery_4    new8  p105  2030    3.027183
# 426  battery_4    new8  p105  2035    3.027183
# 679  battery_4   new18  p105  2035  751.985721
#
# ==================================================
#
#
# Preview of 98pcins_mid_cap_ivrt.csv:
#              i       v     r     t         Val
# 0    battery_2  init-1  p105  2010    2.000000
# 1    battery_2  init-1  p105  2015    2.000000
# 2    battery_2  init-1  p105  2020    2.000000
# 373  battery_2   new23  p105  2040    1.633275
# 374  battery_2   new23  p105  2045    1.633275
# 375  battery_2   new23  p105  2050    1.633275
# 452  battery_2   new33  p105  2050  125.992525
# 497  battery_4    new8  p105  2025    4.239023
# 498  battery_4    new8  p105  2030    4.239023
# 499  battery_4    new8  p105  2035    4.239023
#
# ==================================================
#
#
# Preview of base_nuclear_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
# 132  battery_2    new8  p105  2025  4.547474e-13
# 133  battery_2    new8  p105  2030  4.547474e-13
# 134  battery_2    new8  p105  2035  4.547474e-13
# 216  battery_2   new18  p105  2035  9.308094e-02
# 217  battery_2   new18  p105  2040  9.308094e-02
# 218  battery_2   new18  p105  2045  9.308094e-02
# 302  battery_2   new33  p105  2050  9.150963e+02
#
# ==================================================
#
#
# Preview of base_re_cap_ivrt.csv:
#              i       v     r     t        Val
# 0    battery_2  init-1  p105  2010   2.000000
# 1    battery_2  init-1  p105  2015   2.000000
# 2    battery_2  init-1  p105  2020   2.000000
# 295  battery_2   new23  p105  2040   3.240436
# 296  battery_2   new23  p105  2045   3.240436
# 297  battery_2   new23  p105  2050   3.240436
# 630  battery_4   new18  p105  2035   1.929627
# 631  battery_4   new18  p105  2040   1.929627
# 632  battery_4   new18  p105  2045   1.929627
# 883  battery_4   new28  p105  2045  96.011299
#
# ==================================================
#
#
# Preview of base_solar_cap_ivrt.csv:
#                i       v     r     t           Val
# 0      battery_2  init-1  p105  2010  2.000000e+00
# 1      battery_2  init-1  p105  2015  2.000000e+00
# 2      battery_2  init-1  p105  2020  2.000000e+00
# 330    battery_2   new33  p105  2050  4.292306e-01
# 478    battery_4   new13  p105  2030  4.294132e-13
# 479    battery_4   new13  p105  2035  4.294132e-13
# 480    battery_4   new13  p105  2040  4.294132e-13
# 1807  battery_10   new13  p105  2030  6.180162e-13
# 1808  battery_10   new13  p105  2035  6.180162e-13
# 1809  battery_10   new13  p105  2040  6.180162e-13
#
# ==================================================
#
#
# Preview of base_wind_cap_ivrt.csv:
#              i       v     r     t          Val
# 0    battery_2  init-1  p105  2010     2.000000
# 1    battery_2  init-1  p105  2015     2.000000
# 2    battery_2  init-1  p105  2020     2.000000
# 288  battery_2   new23  p105  2040  1890.348623
# 289  battery_2   new23  p105  2045  1890.348623
# 290  battery_2   new23  p105  2050  1890.348623
# 644  battery_4   new18  p105  2035    37.939436
# 645  battery_4   new18  p105  2040    37.939436
# 646  battery_4   new18  p105  2045    37.939436
# 805  battery_4   new28  p105  2045     9.772483
#
# ==================================================
#
#
# Preview of base_mid_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
# 132  battery_2    new8  p105  2025  4.547474e-13
# 133  battery_2    new8  p105  2030  4.547474e-13
# 134  battery_2    new8  p105  2035  4.547474e-13
# 309  battery_2   new23  p105  2040  1.181475e+02
# 310  battery_2   new23  p105  2045  1.181475e+02
# 311  battery_2   new23  p105  2050  1.181475e+02
# 402  battery_2   new33  p105  2050  4.050410e+00
#
# ==================================================
#
#
# Preview of med10yr_nuclear_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
# 216  battery_2   new18  p105  2035  4.236391e-03
# 217  battery_2   new18  p105  2040  4.236391e-03
# 218  battery_2   new18  p105  2045  4.236391e-03
# 342  battery_4    new8  p105  2025  2.273737e-13
# 343  battery_4    new8  p105  2030  2.273737e-13
# 344  battery_4    new8  p105  2035  2.273737e-13
# 615  battery_4   new18  p105  2035  9.906818e-01
#
# ==================================================
#
#
# Preview of med10yr_re_cap_ivrt.csv:
#              i       v     r     t         Val
# 0    battery_2  init-1  p105  2010    2.000000
# 1    battery_2  init-1  p105  2015    2.000000
# 2    battery_2  init-1  p105  2020    2.000000
# 304  battery_2   new23  p105  2040    1.755250
# 305  battery_2   new23  p105  2045    1.755250
# 306  battery_2   new23  p105  2050    1.755250
# 611  battery_4   new18  p105  2035  212.708511
# 612  battery_4   new18  p105  2040  212.708511
# 613  battery_4   new18  p105  2045  212.708511
# 843  battery_4   new28  p105  2045  204.575401
#
# ==================================================
#
#
# Preview of med10yr_solar_cap_ivrt.csv:
#              i       v     r     t        Val
# 0    battery_2  init-1  p105  2010   2.000000
# 1    battery_2  init-1  p105  2015   2.000000
# 2    battery_2  init-1  p105  2020   2.000000
# 283  battery_2   new23  p105  2040   8.323287
# 284  battery_2   new23  p105  2045   8.323287
# 285  battery_2   new23  p105  2050   8.323287
# 359  battery_2   new33  p105  2050   5.167575
# 672  battery_4   new18  p105  2035  49.913444
# 673  battery_4   new18  p105  2040  49.913444
# 674  battery_4   new18  p105  2045  49.913444
#
# ==================================================
#
#
# Preview of med10yr_wind_cap_ivrt.csv:
#              i       v     r     t          Val
# 0    battery_2  init-1  p105  2010     2.000000
# 1    battery_2  init-1  p105  2015     2.000000
# 2    battery_2  init-1  p105  2020     2.000000
# 321  battery_2   new23  p105  2040   531.700911
# 322  battery_2   new23  p105  2045   531.700911
# 323  battery_2   new23  p105  2050   531.700911
# 646  battery_4   new18  p105  2035  1638.157181
# 647  battery_4   new18  p105  2040  1638.157181
# 648  battery_4   new18  p105  2045  1638.157181
# 999  battery_6   new13  p105  2030   518.013988
#
# ==================================================
#
#
# Preview of med10yr_mid_cap_ivrt.csv:
#              i       v     r     t           Val
# 0    battery_2  init-1  p105  2010  2.000000e+00
# 1    battery_2  init-1  p105  2015  2.000000e+00
# 2    battery_2  init-1  p105  2020  2.000000e+00
# 132  battery_2    new8  p105  2025  9.094947e-13
# 133  battery_2    new8  p105  2030  9.094947e-13
# 134  battery_2    new8  p105  2035  9.094947e-13
# 312  battery_2   new23  p105  2040  1.844500e-01
# 313  battery_2   new23  p105  2045  1.844500e-01
# 314  battery_2   new23  p105  2050  1.844500e-01
# 353  battery_2   new28  p105  2045  9.787351e-01
#
# ==================================================
#
#
# Preview of medins_nuclear_cap_ivrt.csv:
#               i       v     r     t        Val
# 0     battery_2  init-1  p105  2010   2.000000
# 1     battery_2  init-1  p105  2015   2.000000
# 2     battery_2  init-1  p105  2020   2.000000
# 570   battery_4   new18  p105  2035   0.238000
# 571   battery_4   new18  p105  2040   0.238000
# 572   battery_4   new18  p105  2045   0.238000
# 678   battery_4   new23  p105  2040   0.360371
# 679   battery_4   new23  p105  2045   0.360371
# 680   battery_4   new23  p105  2050   0.360371
# 1551  Coal-IGCC  init-1  p105  2010  85.000000
#
# ==================================================
#
#
# Preview of medins_re_cap_ivrt.csv:
#              i       v     r     t         Val
# 0    battery_2  init-1  p105  2010    2.000000
# 1    battery_2  init-1  p105  2015    2.000000
# 2    battery_2  init-1  p105  2020    2.000000
# 300  battery_2   new23  p105  2040    1.822400
# 301  battery_2   new23  p105  2045    1.822400
# 302  battery_2   new23  p105  2050    1.822400
# 678  battery_4   new18  p105  2035  254.322842
# 679  battery_4   new18  p105  2040  254.322842
# 680  battery_4   new18  p105  2045  254.322842
# 939  battery_4   new28  p105  2045   60.525125
#
# ==================================================
#
#
# Preview of medins_solar_cap_ivrt.csv:
#              i       v     r     t         Val
# 0    battery_2  init-1  p105  2010    2.000000
# 1    battery_2  init-1  p105  2015    2.000000
# 2    battery_2  init-1  p105  2020    2.000000
# 276  battery_2   new23  p105  2040   27.426675
# 277  battery_2   new23  p105  2045   27.426675
# 278  battery_2   new23  p105  2050   27.426675
# 342  battery_2   new33  p105  2050   38.241880
# 645  battery_4   new18  p105  2035  350.155938
# 646  battery_4   new18  p105  2040  350.155938
# 647  battery_4   new18  p105  2045  350.155938
#
# ==================================================
#
#
# Preview of medins_wind_cap_ivrt.csv:
#              i       v     r     t          Val
# 0    battery_2  init-1  p105  2010     2.000000
# 1    battery_2  init-1  p105  2015     2.000000
# 2    battery_2  init-1  p105  2020     2.000000
# 270  battery_2   new23  p105  2040   144.213125
# 271  battery_2   new23  p105  2045   144.213125
# 272  battery_2   new23  p105  2050   144.213125
# 646  battery_4   new18  p105  2035  1265.994493
# 647  battery_4   new18  p105  2040  1265.994493
# 648  battery_4   new18  p105  2045  1265.994493
# 822  battery_4   new28  p105  2045    50.802588
#
# ==================================================
#
#
# Preview of medins_mid_cap_ivrt.csv:
#              i       v     r     t        Val
# 0    battery_2  init-1  p105  2010   2.000000
# 243  battery_2   new18  p105  2045  1.278442e+03
# 325  battery_2   new23  p105  2040  4.206732e+03
# 326  battery_2   new23  p105  2045  2.588456e+03
# 327  battery_2   new23  p105  2050  4.670054e+03
#
# ==================================================

# %%
# delete the v column
for file_name, data in indiana_all_data.items():
    try:
        if 'v' in data.columns:
            indiana_all_data[file_name] = data.drop(columns=['v'])
            print(f"Column 'v' removed from: {file_name}")
        else:
            print(f"Column 'v' not found in {file_name}, skipping.")
    except Exception as e:
        print(f"Error processing {file_name}: {e}")
        
print("Update complete. 'v' column removed where present.")

for file_name, data in indiana_all_data.items():
    print(f'\nPreview of {file_name}:')
    print(data.head(10))
    print("\n" + "="*50 + "\n")
# Out:
# Column 'v' removed from: 98pc10yr_nuclear_cap_ivrt.csv
# Column 'v' removed from: 98pc10yr_re_cap_ivrt.csv
# Column 'v' removed from: 98pc10yr_solar_cap_ivrt.csv
# Column 'v' removed from: 98pc10yr_wind_cap_ivrt.csv
# Column 'v' removed from: 98pc10yr_mid_cap_ivrt.csv
# Column 'v' removed from: 98pcins_nuclear_cap_ivrt.csv
# Column 'v' removed from: 98pcins_re_cap_ivrt.csv
# Column 'v' removed from: 98pcins_solar_cap_ivrt.csv
# Column 'v' removed from: 98pcins_wind_cap_ivrt.csv
# Column 'v' removed from: 98pcins_mid_cap_ivrt.csv
# Column 'v' removed from: base_nuclear_cap_ivrt.csv
# Column 'v' removed from: base_re_cap_ivrt.csv
# Column 'v' removed from: base_solar_cap_ivrt.csv
# Column 'v' removed from: base_wind_cap_ivrt.csv
# Column 'v' removed from: base_mid_cap_ivrt.csv
# Column 'v' removed from: med10yr_nuclear_cap_ivrt.csv
# Column 'v' removed from: med10yr_re_cap_ivrt.csv
# Column 'v' removed from: med10yr_solar_cap_ivrt.csv
# Column 'v' removed from: med10yr_wind_cap_ivrt.csv
# Column 'v' removed from: med10yr_mid_cap_ivrt.csv
# Column 'v' removed from: medins_nuclear_cap_ivrt.csv
# Column 'v' removed from: medins_re_cap_ivrt.csv
# Column 'v' removed from: medins_solar_cap_ivrt.csv
# Column 'v' removed from: medins_wind_cap_ivrt.csv
# Column 'v' removed from: medins_mid_cap_ivrt.csv
# Column 'v' removed from: 98pc10yr_nuclear_gen_ivrt.csv
# Column 'v' removed from: 98pc10yr_re_gen_ivrt.csv
# Column 'v' removed from: 98pc10yr_solar_gen_ivrt.csv
# Column 'v' removed from: 98pc10yr_wind_gen_ivrt.csv
# Column 'v' removed from: 98pc10yr_mid_gen_ivrt.csv
# Column 'v' removed from: 98pcins_nuclear_gen_ivrt.csv
# Column 'v' removed from: 98pcins_re_gen_ivrt.csv
# Column 'v' removed from: 98pcins_solar_gen_ivrt.csv
# Column 'v' removed from: 98pcins_wind_gen_ivrt.csv
# Column 'v' removed from: 98pcins_mid_gen_ivrt.csv
# Column 'v' removed from: base_nuclear_gen_ivrt.csv
# Column 'v' removed from: base_re_gen_ivrt.csv
# Column 'v' removed from: base_solar_gen_ivrt.csv
# Column 'v' removed from: base_wind_gen_ivrt.csv
# Column 'v' removed from: base_mid_gen_ivrt.csv
# Column 'v' removed from: med10yr_nuclear_gen_ivrt.csv
# Column 'v' removed from: med10yr_re_gen_ivrt.csv
# Column 'v' removed from: med10yr_solar_gen_ivrt.csv
# Column 'v' removed from: med10yr_wind_gen_ivrt.csv
# Column 'v' removed from: med10yr_mid_gen_ivrt.csv
# Column 'v' removed from: medins_nuclear_gen_ivrt.csv
# Column 'v' removed from: medins_re_gen_ivrt.csv
# Column 'v' removed from: medins_solar_gen_ivrt.csv
# Column 'v' removed from: medins_wind_gen_ivrt.csv
# Column 'v' removed from: medins_mid_gen_ivrt.csv
# Update complete. 'v' column removed where present.
#
# Preview of 98pc10yr_nuclear_cap_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  2.000000e+00
# 1    battery_2  p105  2015  2.000000e+00
# 2    battery_2  p105  2020  2.000000e+00
# 132  battery_2  p105  2025  2.273737e-13
# 133  battery_2  p105  2030  2.273737e-13
# 134  battery_2  p105  2035  2.273737e-13
# 572  battery_4  p105  2035  3.183250e-01
# 573  battery_4  p105  2040  3.183250e-01
# 574  battery_4  p105  2045  3.183250e-01
# 763  battery_4  p105  2050  6.823898e+02
#
# ==================================================
#
#
# Preview of 98pc10yr_re_cap_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  2.000000e+00
# 1    battery_2  p105  2015  2.000000e+00
# 2    battery_2  p105  2020  2.000000e+00
# 261  battery_2  p105  2040  4.170950e+00
# 262  battery_2  p105  2045  4.170950e+00
# 263  battery_2  p105  2050  4.170950e+00
# 369  battery_4  p105  2025 -2.273737e-13
# 370  battery_4  p105  2030 -2.273737e-13
# 371  battery_4  p105  2035 -2.273737e-13
# 607  battery_4  p105  2035  9.521170e-01
#
# ==================================================
#
#
# Preview of 98pc10yr_solar_cap_ivrt.csv:
#              i     r     t        Val
# 0    battery_2  p105  2010   2.000000
# 1    battery_2  p105  2015   2.000000
# 2    battery_2  p105  2020   2.000000
# 294  battery_2  p105  2040   0.243950
# 295  battery_2  p105  2045   0.243950
# 296  battery_2  p105  2050   0.243950
# 375  battery_2  p105  2050  14.750900
# 691  battery_4  p105  2035   6.035812
# 692  battery_4  p105  2040   6.035812
# 693  battery_4  p105  2045   6.035812
#
# ==================================================
#
#
# Preview of 98pc10yr_wind_cap_ivrt.csv:
#               i     r     t         Val
# 0     battery_2  p105  2010    2.000000
# 1     battery_2  p105  2015    2.000000
# 2     battery_2  p105  2020    2.000000
# 204   battery_2  p105  2035    8.483000
# 205   battery_2  p105  2040    8.483000
# 206   battery_2  p105  2045    8.483000
# 279   battery_2  p105  2040  116.575158
# 280   battery_2  p105  2045  116.575158
# 281   battery_2  p105  2050  116.575158
# 1004  battery_6  p105  2030  546.574756
#
# ==================================================
#
#
# Preview of 98pc10yr_mid_cap_ivrt.csv:
#               i     r     t         Val
# 0     battery_2  p105  2010    2.000000
# 1     battery_2  p105  2015    2.000000
# 2     battery_2  p105  2020    2.000000
# 635   battery_4  p105  2035  807.966950
# 636   battery_4  p105  2040  807.966950
# 637   battery_4  p105  2045  807.966950
# 881   battery_4  p105  2050   13.663296
# 1213  battery_6  p105  2040    0.270272
# 1214  battery_6  p105  2045    0.270272
# 1215  battery_6  p105  2050    0.270272
#
# ==================================================
#
#
# Preview of 98pcins_nuclear_cap_ivrt.csv:
#              i     r     t       Val
# 0    battery_2  p105  2010  2.000000
# 1    battery_2  p105  2015  2.000000
# 2    battery_2  p105  2020  2.000000
# 205  battery_2  p105  2035  0.348846
# 206  battery_2  p105  2040  0.348846
# 207  battery_2  p105  2045  0.348846
# 345  battery_4  p105  2025  4.239023
# 346  battery_4  p105  2030  4.239023
# 347  battery_4  p105  2035  4.239023
# 624  battery_4  p105  2035  0.495377
#
# ==================================================
#
#
# Preview of 98pcins_re_cap_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  2.000000e+00
# 1    battery_2  p105  2015  2.000000e+00
# 2    battery_2  p105  2020  2.000000e+00
#
ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  2.000000e+00
# 1    battery_2  p105  2015  2.000000e+00
# 2    battery_2  p105  2020  2.000000e+00
# 132  battery_2  p105  2025  9.094947e-13
# 133  battery_2  p105  2030  9.094947e-13
# 134  battery_2  p105  2035  9.094947e-13
# 312  battery_2  p105  2040  1.844500e-01
# 313  battery_2  p105  2045  1.844500e-01
# 314  battery_2  p105  2050  1.844500e-01
# 353  battery_2  p105  2045  9.787351e-01
#
# ==================================================
#
#
# Preview of medins_nuclear_cap_ivrt.csv:
#               i     r     t        Val
# 0     battery_2  p105  2010   2.000000
# 1     battery_2  p105  2015   2.000000
# 2     battery_2  p105  2020   2.000000
# 570   battery_4  p105  2035   0.238000
# 571   battery_4  p105  2040   0.238000
# 572   battery_4  p105  2045   0.238000
# 678   battery_4  p105  2040   0.360371
# 679   battery_4  p105  2045   0.360371
# 680   battery_4  p105  2050   0.360371
# 1551  Coal-IGCC  p105  2010  85.000000
#
# ==================================================
#
#
# Preview of medins_re_cap_ivrt.csv:
#              i     r     t         Val
# 0    battery_2  p105  2010    2.000000
# 1    battery_2  p105  2015    2.000000
# 2    battery_2  p105  2020    2.000000
# 300  battery_2  p105  2040    1.822400
# 301  battery_2  p105  2045    1.822400
# 302  battery_2  p105  2050    1.822400
# 678  battery_4  p105  2035  254.322842
# 679  battery_4  p105  2040  254.322842
# 680  battery_4  p105  2045  254.322842
# 939  battery_4  p105  2045   60.525125
#
# ==================================================
#
#
# Preview of medins_solar_cap_ivrt.csv:
#              i     r     t         Val
# 0    battery_2  p105  2010    2.000000
# 1    battery_2  p105  2015    2.000000
# 2    battery_2  p105  2020    2.000000
# 276  battery_2  p105  2040   27.426675
# 277  battery_2  p105  2045   27.426675
# 278  battery_2  p105  2050   27.426675
# 342  battery_2  p105  2050   38.241880
# 645  battery_4  p105  2035  350.155938
# 646  battery_4  p105  2040  350.155938
# 647  battery_4  p105  2045  350.155938
#
# ==================================================
#
#
# Preview of medins_wind_cap_ivrt.csv:
#              i     r     t          Val
# 0    battery_2  p105  2010     2.000000
# 1    battery_2  p105  2015     2.000000
# 2    battery_2  p105  2020     2.000000
# 270  battery_2  p105  2040   144.213125
# 271  battery_2  p105  2045   144.213125
# 272  battery_2  p105  2050   144.213125
# 646  battery_4  p105  2035  1265.994493
# 647  battery_4  p105  2040  1265.994493
# 648  battery_4  p105  2045  1265.994493
# 822  battery_4  p105  2045    50.802588
#
# ==================================================
#
#
# Preview of medins_mid_cap_ivrt.csv:
#              i     r     t        Val
# 0    battery_2  p105  2010   2.000000
# 1    battery_2  p105  2015   2.000000
# 2    battery_2  p105  2020   2.000000
# 242  battery_2  p105  2035   1.627746
# 243  battery_2  p105  2040   1.627746
# 244  battery_2  p105  2045   1.627746
# 321  battery_2  p105  2040   3.778250
# 322  battery_2  p105  2045   3.778250
# 323  battery_2  p105  2050   3.778250
# 411  battery_2  p105  2050  15.449389
#
# ==================================================
#
#
# Preview of 98pc10yr_nuclear_gen_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  3.630018e+02
# 1    battery_2  p105  2015  7.840000e+01
# 2    battery_2  p105  2020  3.598185e+02
#
gen_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  3.630018e+02
# 1    battery_2  p105  2015  7.840000e+01
# 2    battery_2  p105  2020  3.598185e+02
# 283  battery_2  p105  2040  4.770363e+04
# 284  battery_2  p105  2045  3.598890e+04
# 285  battery_2  p105  2050  1.839027e+04
# 350  battery_2  p105  2050  5.955368e+04
# 505  battery_4  p105  2030 -1.029576e-09
# 659  battery_4  p105  2035  6.351233e+05
# 660  battery_4  p105  2040  5.456400e+05
#
# ==================================================
#
#
# Preview of medins_wind_gen_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  3.630018e+02
# 1    battery_2  p105  2015  7.840000e+01
# 2    battery_2  p105  2020  3.598185e+02
# 138  battery_2  p105  2025  4.111583e-11
# 279  battery_2  p105  2040  1.958731e+05
# 280  battery_2  p105  2045  7.265572e+04
# 281  battery_2  p105  2050  1.006142e+05
# 665  battery_4  p105  2035  1.001595e+06
# 666  battery_4  p105  2040  1.354878e+06
# 667  battery_4  p105  2045  1.624621e+06
#
# ==================================================
#
#
# Preview of medins_mid_gen_ivrt.csv:
#              i     r     t           Val
# 0    battery_2  p105  2010  3.630018e+02
# 1    battery_2  p105  2015  7.840000e+01
# 2    battery_2  p105  2020  3.598185e+02
# 193  battery_2  p105  2030  1.607623e-08
# 241  battery_2  p105  2035  1.384290e+03
# 242  battery_2  p105  2040  1.052891e+03
# 243  battery_2  p105  2045  1.278442e+03
# 325  battery_2  p105  2040  4.206732e+03
# 326  battery_2  p105  2045  2.588456e+03
# 327  battery_2  p105  2050  4.670054e+03
#
# ==================================================

# %%
# group the year and equipment to have the Val for each quipment in each year
# processed data will be stored in indiana_all_data_processed
indiana_all_data_processed = {}

for file_name, data in indiana_all_data.items():
    try:
        grouped_data = data.groupby(['t', 'i'], as_index=False).agg({'Val':'sum'})
        indiana_all_data_processed[file_name] = grouped_data
        print(f"Aggregated data for: {file_name}")
        
    except Exception as e:
        print(f"Error processing {file_name}: {e}")
        
print("Data aggregation complete. Processed data stored in 'indiana_all_data_processed'.")

for file_name, data in indiana_all_data_processed.items():
    print(f'\nPreview of {file_name}:')
    print(data.head(10))
    print("\n" + "="*50 + "\n")
# Out:
# Aggregated data for: 98pc10yr_nuclear_cap_ivrt.csv
# Aggregated data for: 98pc10yr_re_cap_ivrt.csv
# Aggregated data for: 98pc10yr_solar_cap_ivrt.csv
# Aggregated data for: 98pc10yr_wind_cap_ivrt.csv
# Aggregated data for: 98pc10yr_mid_cap_ivrt.csv
# Aggregated data for: 98pcins_nuclear_cap_ivrt.csv
# Aggregated data for: 98pcins_re_cap_ivrt.csv
# Aggregated data for: 98pcins_solar_cap_ivrt.csv
# Aggregated data for: 98pcins_wind_cap_ivrt.csv
# Aggregated data for: 98pcins_mid_cap_ivrt.csv
# Aggregated data for: base_nuclear_cap_ivrt.csv
# Aggregated data for: base_re_cap_ivrt.csv
# Aggregated data for: base_solar_cap_ivrt.csv
# Aggregated data for: base_wind_cap_ivrt.csv
# Aggregated data for: base_mid_cap_ivrt.csv
# Aggregated data for: med10yr_nuclear_cap_ivrt.csv
# Aggregated data for: med10yr_re_cap_ivrt.csv
# Aggregated data for: med10yr_solar_cap_ivrt.csv
# Aggregated data for: med10yr_wind_cap_ivrt.csv
# Aggregated data for: med10yr_mid_cap_ivrt.csv
# Aggregated data for: medins_nuclear_cap_ivrt.csv
# Aggregated data for: medins_re_cap_ivrt.csv
# Aggregated data for: medins_solar_cap_ivrt.csv
# Aggregated data for: medins_wind_cap_ivrt.csv
# Aggregated data for: medins_mid_cap_ivrt.csv
# Aggregated data for: 98pc10yr_nuclear_gen_ivrt.csv
# Aggregated data for: 98pc10yr_re_gen_ivrt.csv
# Aggregated data for: 98pc10yr_solar_gen_ivrt.csv
# Aggregated data for: 98pc10yr_wind_gen_ivrt.csv
# Aggregated data for: 98pc10yr_mid_gen_ivrt.csv
# Aggregated data for: 98pcins_nuclear_gen_ivrt.csv
# Aggregated data for: 98pcins_re_gen_ivrt.csv
# Aggregated data for: 98pcins_solar_gen_ivrt.csv
# Aggregated data for: 98pcins_wind_gen_ivrt.csv
# Aggregated data for: 98pcins_mid_gen_ivrt.csv
# Aggregated data for: base_nuclear_gen_ivrt.csv
# Aggregated data for: base_re_gen_ivrt.csv
# Aggregated data for: base_solar_gen_ivrt.csv
# Aggregated data for: base_wind_gen_ivrt.csv
# Aggregated data for: base_mid_gen_ivrt.csv
# Aggregated data for: med10yr_nuclear_gen_ivrt.csv
# Aggregated data for: med10yr_re_gen_ivrt.csv
# Aggregated data for: med10yr_solar_gen_ivrt.csv
# Aggregated data for: med10yr_wind_gen_ivrt.csv
# Aggregated data for: med10yr_mid_gen_ivrt.csv
# Aggregated data for: medins_nuclear_gen_ivrt.csv
# Aggregated data for: medins_re_gen_ivrt.csv
# Aggregated data for: medins_solar_gen_ivrt.csv
# Aggregated data for: medins_wind_gen_ivrt.csv
# Aggregated data for: medins_mid_gen_ivrt.csv
# Data aggregation complete. Processed data stored in 'indiana_all_data_processed'.
#
# Preview of 98pc10yr_nuclear_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pc10yr_re_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pc10yr_solar_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pc10yr_wind_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pc10yr_mid_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pcins_nuclear_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pcins_re_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pcins_solar_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pcins_wind_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pcins_mid_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of base_nuclear_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of base_re_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of base_solar_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of base_wind_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of base_mid_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of med10yr_nuclear_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of med10yr_re_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of med10yr_solar_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of med10yr_wind_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of med10yr_mid_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of medins_nuclear_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of medins_re_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of medins_solar_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of medins_wind_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of medins_mid_cap_ivrt.csv:
#       t           i     Val
# 0  2010   Coal-IGCC   223.0
# 1  2010  CoalOldScr  3075.0
# 2  2010  CoalOldUns  2244.0
# 3  2010      Gas-CC  1062.0
# 4  2010      Gas-CT  1301.4
# 5  2010   battery_2     2.0
# 6  2010      hydEND    15.4
# 7  2010   lfill-gas    36.8
# 8  2010       o-g-s   127.7
# 9  2015   Coal-IGCC   223.0
#
# ==================================================
#
#
# Preview of 98pc10yr_nuclear_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pc10yr_re_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pc10yr_solar_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pc10yr_wind_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pc10yr_mid_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pcins_nuclear_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pcins_re_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pcins_solar_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pcins_wind_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of 98pcins_mid_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of base_nuclear_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of base_re_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of base_solar_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of base_wind_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of base_mid_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of med10yr_nuclear_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of med10yr_re_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of med10yr_solar_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of med10yr_wind_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of med10yr_mid_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of medins_nuclear_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of medins_re_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of medins_solar_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of medins_wind_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================
#
#
# Preview of medins_mid_gen_ivrt.csv:
#       t           i           Val
# 0  2010   Coal-IGCC  1.601438e+06
# 1  2010  CoalOldScr  2.031099e+07
# 2  2010  CoalOldUns  1.461770e+07
# 3  2010      Gas-CC  3.714707e+06
# 4  2010      Gas-CT  5.942913e+05
# 5  2010   battery_2  3.630018e+02
# 6  2010      hydEND  5.339850e+04
# 7  2010   lfill-gas  1.685831e+05
# 8  2010  wind-ons_6  1.704172e+06
# 9  2010  wind-ons_7  1.714740e+06
#
# ==================================================

# %%
# generate the color scheme
# https://m2.material.io/design/color/the-color-system.html#color-theme-creation
color_scheme = {
    "dupv_3": "#D50000",
    "wind-ons_8": "#C51162",
    "pvb1_2": "#AA00FF",
    "lfill-gas": "#6200EA",
    "distpv": "#00796B",
    "dupv_2": "#2962FF",
    "battery_6": "#0091EA",
    "Gas-CC": "#00B8D4",
    "battery_10": "#00BFA5",
    "upv_3": "#00C853",
    "battery_2": "#64DD17",
    "Gas-CT": "#AEEA00",
    "battery_4": "#FFD600",
    "pvb1_3": "#FFAB00",
    "o-g-s": "#FF6D00",
    "CoalOldUns": "#311B92",
    "hydEND": "#6D4C41",
    "CoalOldScr": "#546E7A",
    "wind-ons_7": "#FF8A80",
    "Coal-IGCC_coal-CCS_mod": "#FF80AB",
    "battery_8": "#EA80FC",
    "wind-ofs_13": "#B388FF",
    "Gas-CC_Gas-CC-CCS_mod": "#8C9EFF",
    "Coal-IGCC": "#82B1FF",
    "CoalOldScr_coal-CCS_mod": "#80D8FF",
    "wind-ons_6": "#84FFFF",
    "wind-ofs_5": "#A7FFEB"
}

# %%
# set up the plotting 
chart_sequence = np.array([
    ['base_nuclear_gen_ivrt.csv', 'med10yr_nuclear_gen_ivrt.csv', '98pc10yr_nuclear_gen_ivrt.csv', 'base_nuclear_cap_ivrt.csv', 'med10yr_nuclear_cap_ivrt.csv', '98pc10yr_nuclear_cap_ivrt.csv'],
    ['base_re_gen_ivrt.csv', 'med10yr_re_gen_ivrt.csv', '98pc10yr_re_gen_ivrt.csv', 'base_re_cap_ivrt.csv', 'med10yr_re_cap_ivrt.csv', '98pc10yr_re_cap_ivrt.csv'],
    ['base_solar_gen_ivrt.csv', 'med10yr_solar_gen_ivrt.csv', '98pc10yr_solar_gen_ivrt.csv', 'base_solar_cap_ivrt.csv', 'med10yr_solar_cap_ivrt.csv', '98pc10yr_solar_cap_ivrt.csv'],
    ['base_wind_gen_ivrt.csv', 'med10yr_wind_gen_ivrt.csv', '98pc10yr_wind_gen_ivrt.csv', 'base_wind_cap_ivrt.csv', 'med10yr_wind_cap_ivrt.csv', '98pc10yr_wind_cap_ivrt.csv'],
    ['base_mid_gen_ivrt.csv', 'med10yr_mid_gen_ivrt.csv', '98pc10yr_mid_gen_ivrt.csv', 'base_mid_cap_ivrt.csv', 'med10yr_mid_cap_ivrt.csv', '98pc10yr_mid_cap_ivrt.csv'],
    ['base_nuclear_gen_ivrt.csv', 'medins_nuclear_gen_ivrt.csv', '98pcins_nuclear_gen_ivrt.csv', 'base_nuclear_cap_ivrt.csv', 'medins_nuclear_cap_ivrt.csv', '98pcins_nuclear_cap_ivrt.csv'],
    ['base_re_gen_ivrt.csv', 'medins_re_gen_ivrt.csv', '98pcins_re_gen_ivrt.csv', 'base_re_cap_ivrt.csv', 'medins_re_cap_ivrt.csv', '98pcins_re_cap_ivrt.csv'],
    ['base_solar_gen_ivrt.csv', 'medins_solar_gen_ivrt.csv', '98pcins_solar_gen_ivrt.csv', 'base_solar_cap_ivrt.csv', 'medins_solar_cap_ivrt.csv', '98pcins_solar_cap_ivrt.csv'],
    ['base_wind_gen_ivrt.csv', 'medins_wind_gen_ivrt.csv', '98pcins_wind_gen_ivrt.csv', 'base_wind_cap_ivrt.csv', 'medins_wind_cap_ivrt.csv', '98pcins_wind_cap_ivrt.csv'],
    ['base_mid_gen_ivrt.csv', 'medins_mid_gen_ivrt.csv', '98pcins_mid_gen_ivrt.csv', 'base_mid_cap_ivrt.csv', 'medins_mid_cap_ivrt.csv', '98pcins_mid_cap_ivrt.csv']
])

load = ['without extra load', 'with median extra load', 'with 98th percentile extra load', 'without extra load', 'with median extra load', 'with 98th percentile extra load']
energy = ["nuclear", "renewables", "solar", "wind", "mid case", "nuclear", "renewables", "solar", "wind", "mid case"]
transition_mode = ['10yr', '10yr', '10yr', '10yr', '10yr', 'ins', 'ins', 'ins', 'ins', 'ins']
load_senario = ["98pc10yr", "98pcins", "base", "med10yr", "medins"]
energy_senario = ["nuclear", "re", "solar", "wind", "mid"]

# %%
# generate the plots
os.makedirs("final figures", exist_ok=True)

for i in range(10):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
    for j, ax in enumerate(axes.flat):
        sub_data = indiana_all_data_processed[chart_sequence[i][j]]
        
        pivot_data = sub_data.pivot_table(index='t', columns='i', values='Val', aggfunc='sum').fillna(0)
        tech_catgories = pivot_data.columns
        
        bar_width = 2.5
        
        bottom = None
        for category in tech_catgories:
            color = color_scheme.get(category, "#333333")
            ax.bar(
                pivot_data.index,
                pivot_data[category],
                bottom=bottom,
                color=color,
                width=bar_width,
                label=category
            )
            bottom = bottom + pivot_data[category] if bottom is not None else pivot_data[category]
        
        subplot_letter = chr(97 + j)
        ax.text(
            0.99, 0.98,
            f"({subplot_letter})",
            transform=ax.transAxes,
            fontsize=10,
            ha='right',
            va='top'
        )

        ax.set_xlabel("Year")
        if j <= 2:
            ax.set_ylabel(f"Electricity generation {load[j]}")
            ax.set_ylim(0, 1.5*1e8)
        else: 
            ax.set_ylabel(f"Electricity capacity {load[j]}")
            ax.set_ylim(0, 30000)
    
    if i <= 4:
        fig.suptitle(f"{energy[i].title()} grid scenario with a 10-year transition", fontsize=16, fontweight='semibold', x=0.505, y=0.98)
    else:
        fig.suptitle(f"{energy[i].title()} grid scenario with an instantaneous transition", fontsize=16, fontweight='bold', x=0.505, y=0.98)
    
    handles = []
    labels = []
        
    for category, color in color_scheme.items():
        handles.append(plt.Line2D([0], [0], color=color, lw=6))
        labels.append(category)
        
    fig.legend(
        handles,
        labels,
        loc="center left",
        bbox_to_anchor=(0.995, 0.685),
        fontsize="small"
    )
        
    plt.tight_layout()
    save_path = os.path.join("final figures", f"{energy[i]}_{transition_mode[i]}.png")
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close(fig)
